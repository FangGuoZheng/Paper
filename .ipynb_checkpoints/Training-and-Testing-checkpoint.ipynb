# %%
import pandas as pd
import numpy as np

# %%
oj_data = pd.read_csv("D:/fgz/专利/OJFeatures.csv", engine="python")

# %%
print(oj_data.shape)
oj_data.head()
# Out:
# (22842, 15)
#     sid  sim_id  uid  sim_uid  similarity  similarityThreshold  CPMS  CPMSPC  \
# 0  5409    7322   43      190    0.640000                 0.95     0       2
# 1  5549    5534   43       71    0.511628                 0.85     0       2
# 2  6134    4991   29       20    0.828571                 0.90     0       4
# 3  6638    5825   50       72    0.752941                 0.92     0       3
# 4  6915    6597   28       24    0.784314                 0.92     0       3
#
#    CPTC      ASSR  DL   PR       PCR  RRB  LABEL
# 0     1  0.882609   1  1.0  0.631714  163      1
# 1     1  0.627778   1  1.0  0.631714  163      1
# 2     1  0.775883   1  0.0  0.813397  188      0
# 3     1  0.932974   1  1.0  0.703248  169      1
# 4     1  0.888374   1  1.0  0.586463  128      1

# %%
columns = ['sid', 'sim_id', 'uid', 'sim_uid', 'similarity', 'similarityThreshold', 'CPMS']
oj_data.drop(columns=columns, inplace=True ,axis=1) # "inplace=True" indicate that delete columns in-place

# %%
oj_data.head()
# Out:
#    CPMSPC  CPTC      ASSR  DL   PR       PCR  RRB  LABEL
# 0       2     1  0.882609   1  1.0  0.631714  163      1
# 1       2     1  0.627778   1  1.0  0.631714  163      1
# 2       4     1  0.775883   1  0.0  0.813397  188      0
# 3       3     1  0.932974   1  1.0  0.703248  169      1
# 4       3     1  0.888374   1  1.0  0.586463  128      1

# %%
train_data=oj_data.iloc[0:21842, :]
test_data=oj_data.iloc[21842:oj_data.shape[0], :]

# %%
from sklearn.utils import shuffle

test_data = shuffle(test_data)

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (21842, 8)
# (1000, 8)

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train=train_data.iloc[:, 0:7]
y_train=train_data.iloc[:, 7]
X_test=test_data.iloc[:, 0:7]
y_test=test_data.iloc[:, 7]

# %%
X_train['CPTC'].value_counts()
# Out:
# 1    20560
# 0     1282
# Name: CPTC, dtype: int64

# %%
# fit model no training data
# model1 = XGBClassifier(learning_rate=0.1)
# model2 = XGBClassifier(
#  learning_rate =0.01,
#  n_estimators=5000,
#  max_depth=4,
#  min_child_weight=6,
#  gamma=0,
#  subsample=0.8,
#  colsample_bytree=0.8,
#  reg_alpha=0.005,
#  objective= 'binary:logistic',
#  nthread=4,
#  scale_pos_weight=1,
#  seed=27)

model = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=4,
 min_child_weight=6,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 reg_alpha=0.005,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)

model.fit(X_train, y_train)
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print(accuracy)
# print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# 0.98
# D:\Anaconda\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
eval_set = [(X_test, y_test)]
model.fit(X_train, y_train, early_stopping_rounds=10, eval_metric="logloss", eval_set=eval_set, verbose=True)
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# [0]	validation_0-logloss:0.603104
# Will train until validation_0-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.529589
# [2]	validation_0-logloss:0.468613
# [3]	validation_0-logloss:0.417246
# [4]	validation_0-logloss:0.373396
# [5]	validation_0-logloss:0.336045
# [6]	validation_0-logloss:0.303834
# [7]	validation_0-logloss:0.275738
# [8]	validation_0-logloss:0.251475
# [9]	validation_0-logloss:0.23011
# [10]	validation_0-logloss:0.211321
# [11]	validation_0-logloss:0.195097
# [12]	validation_0-logloss:0.180756
# [13]	validation_0-logloss:0.167883
# [14]	validation_0-logloss:0.156701
# [15]	validation_0-logloss:0.146702
# [16]	validation_0-logloss:0.138021
# [17]	validation_0-logloss:0.130291
# [18]	validation_0-logloss:0.123208
# [19]	validation_0-logloss:0.116933
# [20]	validation_0-logloss:0.111423
# [21]	validation_0-logloss:0.106379
# [22]	validation_0-logloss:0.10213
# [23]	validation_0-logloss:0.098354
# [24]	validation_0-logloss:0.094867
# [25]	validation_0-logloss:0.091691
# [26]	validation_0-logloss:0.089011
# [27]	validation_0-logloss:0.086504
# [28]	validation_0-logloss:0.084311
# [29]	validation_0-logloss:0.082616
# [30]	validation_0-logloss:0.080859
# [31]	validation_0-logloss:0.079232
# [32]	validation_0-logloss:0.077726
# [33]	validation_0-logloss:0.076345
# [34]	validation_0-logloss:0.07524
# [35]	validation_0-logloss:0.074603
# [36]	validation_0-logloss:0.0737
# [37]	validation_0-logloss:0.07269
# [38]	validation_0-logloss:0.071746
# [39]	validation_0-logloss:0.070977
# [40]	validation_0-logloss:0.070364
# [41]	validation_0-logloss:0.069857
# [42]	validation_0-logloss:0.069237
# [43]	validation_0-logloss:0.068503
# [44]	validation_0-logloss:0.067898
# [45]	validation_0-logloss:0.067575
# [46]	validation_0-logloss:0.067294
# [47]	validation_0-logloss:0.06681
# [48]	validation_0-logloss:0.066457
# [49]	validation_0-logloss:0.066034
# [50]	validation_0-logloss:0.065745
# [51]	validation_0-logloss:0.065292
# [52]	validation_0-logloss:0.065057
# [53]	validation_0-logloss:0.064849
# [54]	validation_0-logloss:0.064633
# [55]	validation_0-logloss:0.064534
# [56]	validation_0-logloss:0.064219
# [57]	validation_0-logloss:0.064079
# [58]	validation_0-logloss:0.063811
# [59]	validation_0-logloss:0.06373
# [60]	validation_0-logloss:0.063623
# [61]	validation_0-logloss:0.0634
# [62]	validation_0-logloss:0.063347
# [63]	validation_0-logloss:0.063315
# [64]	validation_0-logloss:0.063107
# [65]	validation_0-logloss:0.062973
# [66]	validation_0-logloss:0.062941
# [67]	validation_0-logloss:0.062885
# [68]	validation_0-logloss:0.062859
# [69]	validation_0-logloss:0.062679
# [70]	validation_0-logloss:0.062663
# [71]	validation_0-logloss:0.062219
# [72]	validation_0-logloss:0.062182
# [73]	validation_0-logloss:0.062145
# [74]	validation_0-logloss:0.062149
# [75]	validation_0-logloss:0.062225
# [76]	validation_0-logloss:0.062087
# [77]	validation_0-logloss:0.061944
# [78]	validation_0-logloss:0.061942
# [79]	validation_0-logloss:0.061942
# [80]	validation_0-logloss:0.061953
# [81]	validation_0-logloss:0.061933
# [82]	validation_0-logloss:0.062058
# [83]	validation_0-logloss:0.061948
# [84]	validation_0-logloss:0.061791
# [85]	validation_0-logloss:0.061666
# [86]	validation_0-logloss:0.061693
# [87]	validation_0-logloss:0.06171
# [88]	validation_0-logloss:0.061747
# [89]	validation_0-logloss:0.061775
# [90]	validation_0-logloss:0.061777
# [91]	validation_0-logloss:0.06175
# [92]	validation_0-logloss:0.061652
# [93]	validation_0-logloss:0.061526
# [94]	validation_0-logloss:0.06143
# [95]	validation_0-logloss:0.061344
# [96]	validation_0-logloss:0.061342
# [97]	validation_0-logloss:0.061262
# [98]	validation_0-logloss:0.061342
# [99]	validation_0-logloss:0.061355
# Accuracy: 97.90%
# D:\Anaconda\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
from xgboost import plot_importance
from matplotlib import pyplot
# plot feature importance
plot_importance(model)
pyplot.show()

# %%
print(model.feature_importances_)
# Out:
# [0.05010933 0.         0.37336007 0.03607872 0.18658893 0.17893586
#  0.17492712]

# %%
from sklearn.metrics import precision_recall_fscore_support as score

precision, recall, fscore, support = score(y_test, predictions, average='macro')

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
print('support: {}'.format(support))
# Out:
# precision: 0.9800787250384024
# recall: 0.9801171368677088
# fscore: 0.97999991999968
# support: None

# %%
from sklearn.ensemble import (RandomForestClassifier, GradientBoostingClassifier)
from sklearn.svm import SVC
grd_clf= GradientBoostingClassifier()
svm_clf = SVC()

# %%
from sklearn.metrics import accuracy_score
# for clf in (grd_clf, svm_clf):
grd_clf.fit(X_train, y_train)
y_pred_gbdt = grd_clf.predict(X_test)
print(grd_clf.__class__.__name__, accuracy_score(y_test, y_pred_gbdt))
precision1, recall1, fscore1, support1 = score(y_test, y_pred_gbdt, average='macro')
print('precision: {}'.format(precision1))
print('recall: {}'.format(recall1))
print('fscore: {}'.format(fscore1))
    
svm_clf.fit(X_train, y_train)
y_pred_svm = svm_clf.predict(X_test)
print(svm_clf.__class__.__name__, accuracy_score(y_test, y_pred_svm))
precision2, recall2, fscore2, support2 = score(y_test, y_pred_svm, average='macro')
print('precision: {}'.format(precision2))
print('recall: {}'.format(recall2))
print('fscore: {}'.format(fscore2))
# Out:
# GradientBoostingClassifier 0.979
# precision: 0.9791079107910792
# recall: 0.9791289945752188
# fscore: 0.978999978999979
# SVC 0.978
# precision: 0.9780785970302099
# recall: 0.978116848826231
# fscore: 0.977999911999648

# %%
importances=grd_clf.feature_importances_

# %%
importances
# Out:
# array([0.01559023, 0.        , 0.36772616, 0.00884426, 0.4479783 ,
#        0.03404445, 0.1258166 ])

# %%
import matplotlib.pyplot as plt

feat_importances = pd.Series(importances, index=oj_data.iloc[:, 0:7].columns)
feat_importances.nlargest(7).plot(kind='barh')

# %%
from sklearn.metrics import roc_curve

fpr_xgb, tpr_xgb, _ = roc_curve(y_test, predictions)
fpr_gbdt, tpr_gbdt, _ = roc_curve(y_test, y_pred_gbdt)
fpr_svm, tpr_svm, _ = roc_curve(y_test, y_pred_svm)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_xgb, tpr_xgb, label='XGBoost', color='r', linestyle='--')
plt.plot(fpr_gbdt, tpr_gbdt, label='GBDT', color='b', linestyle='-')
plt.plot(fpr_svm, tpr_svm, label='SVM', color='orange', linestyle='-.')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.figure(2)
plt.xlim(0, 0.1)
plt.ylim(0.9, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_xgb, tpr_xgb, label='XGBoost', color='r', linestyle='--')
plt.plot(fpr_gbdt, tpr_gbdt, label='GBDT', color='b', linestyle='-')
plt.plot(fpr_svm, tpr_svm, label='SVM', color='orange', linestyle='-.')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()

# %%
draw_data=oj_data.iloc[:, 0:7]

# %%
print(draw_data.shape)
draw_data.head()
# Out:
# (22842, 7)
#    CPMSPC  CPTC      ASSR  DL   PR       PCR  RRB
# 0       2     1  0.882609   1  1.0  0.631714  163
# 1       2     1  0.627778   1  1.0  0.631714  163
# 2       4     1  0.775883   1  0.0  0.813397  188
# 3       3     1  0.932974   1  1.0  0.703248  169
# 4       3     1  0.888374   1  1.0  0.586463  128

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(draw_data)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, oj_data[['LABEL']]], axis = 1)

# %%
finalDf.shape
# Out:
# (22842, 3)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [1, 0]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['LABEL'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
pca1 = PCA(n_components=3)
principalComponents1 = pca1.fit_transform(draw_data)
principalDf1 = pd.DataFrame(data = principalComponents1
             , columns = ['principal component 1', 'principal component 2', 'principal component 3'])

# %%
principalDf1.shape
# Out:
# (22842, 3)

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random

fig = pyplot.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d')
# ax = Axes3D(fig)

ax.scatter(principalDf1['principal component 1'], principalDf1['principal component 2'], principalDf1['principal component 3'])
ax.set_xlabel('X', fontsize = 15)
ax.set_ylabel('Y', fontsize = 15)
ax.set_zlabel('Z', fontsize = 15)
ax.set_title('Unlabel', fontsize = 20)
pyplot.show()

# %%
finalDf1 = pd.concat([principalDf1, oj_data[['LABEL']]], axis = 1)

# %%
finalDf1.shape
# Out:
# (22842, 4)

# %%
fig = pyplot.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d')

targets = [1, 0]
targets_mapping = ['Plagiarism', 'Non-Plagiarism']
colors = ['r', 'b']
markers = ['o', 'v']
for target, color, marker in zip(targets,colors, markers):
    indicesToKeep = finalDf1['LABEL'] == target
    ax.scatter(finalDf1.loc[indicesToKeep, 'principal component 1']
               , finalDf1.loc[indicesToKeep, 'principal component 2']
               , finalDf1.loc[indicesToKeep, 'principal component 3']
               , c = color
               , marker = marker
               , s = 50)
ax.legend(targets_mapping)

ax.set_xlabel('X', fontsize = 15)
ax.set_ylabel('Y', fontsize = 15)
ax.set_zlabel('Z', fontsize = 15)
ax.set_title('Label', fontsize = 20)
pyplot.show()
